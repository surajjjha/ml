# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
a=['1','2','3','40','5','6','7','8']
b=['10','11','12','40','50','60','70','80']
df1=pd.DataFrame({"ab":a,"bc":b})
sns.lineplot(x="ab",y="bc",data=df1)
# Out:
# <AxesSubplot:xlabel='ab', ylabel='bc'>

# %%
data=pd.read_csv('C:\\Users\\Admin\\Downloads\\tips.csv')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
sns.lineplot(x="tip",y="size",data=data)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
sns.lineplot(x="tip",y="price_per_person",data=data)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='price_per_person'>

# %%
sns.lineplot(x="tip",y="total_bill",data=data,hue="sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.lineplot(x="tip",y="total_bill",data=data,hue="sex",style="sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.lineplot(x="tip",y="total_bill",data=data,hue="sex",style="sex",palette="hot")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.distplot(data["tip"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11412\1606609384.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["tip"])
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
sns.distplot(data["size"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11412\719037614.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["size"])
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df2=pd.dataFrame(data.head())
#
# File C:\python310\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'dataFrame'
