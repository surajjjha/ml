# %%
import numpy as np
import pandas as pd

# %%
list_1=[1,2,3,4]
s1=pd.Series(list_1)
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s2=pd.Series([1,2,3,4],index=['a','b','c','d'])
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s3=pd.Series(s2,dtype= float)

# %%
print(s3)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
s4=pd.Series(s2,name='datavalues')

# %%
print(s4)
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: datavalues, dtype: int64

# %%
dict1={'a':1,
       'b':2}
s5=pd.Series(dict1)
print(s5)
# Out:
# a    1
# b    2
# dtype: int64

# %%
s6=pd.Series([1,2,3,4,5])
s7=pd.Series([2,3,4,5,6])
print(s6,s7)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s8=s6+s7
print(s8)
# Out:
# 0     3
# 1     5
# 2     7
# 3     9
# 4    11
# dtype: int64

# %%
min(s8)
# Out:
# 3

# %%
max(s8)
# Out:
# 11

# %%
s8[s8>4]
# Out:
# 1     5
# 2     7
# 3     9
# 4    11
# dtype: int64

# %%
l1=['1','2','3']
l1
# Out:
# ['1', '2', '3']

# %%
df1=pd.DataFrame(l1)
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
listoflist=[['1','2','3'],['4','5','6'],['7','8','9']]
listoflist
# Out:
# [['1', '2', '3'], ['4', '5', '6'], ['7', '8', '9']]

# %%
df2=pd.DataFrame(listoflist)
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dict5={'id':['1','2','3']}
dict5
# Out:
# {'id': ['1', '2', '3']}

# %%
df3=pd.DataFrame(dict5)
df3
# Out:
#   id
# 0  1
# 1  2
# 2  3

# %%
listofdict=[{'a':1,'b':2},{'c':3,'d':4}]
listofdict
# Out:
# [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]

# %%
df4=pd.DataFrame(listofdict)

# %%
df4
# Out:
#      a    b    c    d
# 0  1.0  2.0  NaN  NaN
# 1  NaN  NaN  3.0  4.0

# %%
listofdict=[{'a':1,'b':2},{'a':3,'b':4}]
listofdict
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4}]

# %%
df4=pd.DataFrame(listofdict)
df4
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
listofdict=[{'a':1,'b':2},{'c':1,'d':2}]
listofdict
# Out:
# [{'a': 1, 'b': 2}, {'c': 1, 'd': 2}]

# %%
df4=pd.DataFrame(listofdict)
df4
# Out:
#      a    b    c    d
# 0  1.0  2.0  NaN  NaN
# 1  NaN  NaN  1.0  2.0

# %%
dictofseries={'id':pd.Series([1,2,3]),'sn':pd.Series([4,5,6])}
dictofseries
# Out:
# {'id': 0    1
#  1    2
#  2    3
#  dtype: int64,
#  'sn': 0    4
#  1    5
#  2    6
#  dtype: int64}

# %%
df6=pd.DataFrame(dictofseries)
df6
# Out:
#    id  sn
# 0   1   4
# 1   2   5
# 2   3   6

# %%
pd.read_csv('C:\\Users\\Admin\\Downloads\\mlfile.csv')
# Out:
#   Username; Identifier;One-time password;Recovery code;First name;Last name;Department;Location
# 0  booker12;9012;12se74;rb9012;Rachel;Booker;Sale...
# 1  grey07;2070;04ap67;lg2070;Laura;Grey;Depot;London
# 2  johnson81;4081;30no86;cj4081;Craig;Johnson;Dep...
# 3  jenkins46;9346;14ju73;mj9346;Mary;Jenkins;Engi...
# 4  smith79;5079;09ja61;js5079;Jamie;Smith;Enginee...

# %%
pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv')
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv',nrows=10)
cs1
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv',usecols=[1,5])
cs1
# Out:
#     sex Pstatus
# 0     F       A
# 1     F       T
# 2     F       T
# 3     F       T
# 4     F       T
# ..   ..     ...
# 644   F       T
# 645   F       T
# 646   F       T
# 647   M       T
# 648   M       T
#
# [649 rows x 2 columns]

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv',skiprows=5)
cs1
# Out:
#      GP  F  16  U  GT3  T  3  3.1     other   other.1  ...  4 3.2  2.1  1.1  \
# 0    GP  M  16  U  LE3  T  4    3  services     other  ...  5   4    2    1
# 1    GP  M  16  U  LE3  T  2    2     other     other  ...  4   4    4    1
# 2    GP  F  17  U  GT3  A  4    4     other   teacher  ...  4   1    4    1
# 3    GP  M  15  U  LE3  A  3    2  services     other  ...  4   2    2    1
# 4    GP  M  15  U  GT3  T  3    4     other     other  ...  5   5    1    1
# ..   .. ..  .. ..  ... .. ..  ...       ...       ...  ... ..  ..  ...  ...
# 639  MS  F  19  R  GT3  T  2    3  services     other  ...  5   4    2    1
# 640  MS  F  18  U  LE3  T  3    1   teacher  services  ...  4   3    4    1
# 641  MS  F  18  U  GT3  T  1    1     other     other  ...  1   1    1    1
# 642  MS  M  17  U  LE3  T  3    1  services  services  ...  2   4    5    3
# 643  MS  M  18  R  LE3  T  3    2  services     other  ...  4   4    1    3
#
#      2.2  5 0.1  11  13 13.1
# ...

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv')
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv' )
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv')
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
cs1.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv', na_filter=False)
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 644   False  False  False    False    False    False  False  False  False
# 645   False  False  False    False    False    False  False  False  False
# 646   False  False  False    False    False    False  False  False  False
# 647   False  False  False    False    False    False  False  False  False
# 648   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
cs1.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
cs1.notnull()
# Out:
#      school   sex   age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0      True  True  True     True     True     True  True  True  True  True
# 1      True  True  True     True     True     True  True  True  True  True
# 2      True  True  True     True     True     True  True  True  True  True
# 3      True  True  True     True     True     True  True  True  True  True
# 4      True  True  True     True     True     True  True  True  True  True
# ..      ...   ...   ...      ...      ...      ...   ...   ...   ...   ...
# 644    True  True  True     True     True     True  True  True  True  True
# 645    True  True  True     True     True     True  True  True  True  True
# 646    True  True  True     True     True     True  True  True  True  True
# 647    True  True  True     True     True     True  True  True  True  True
# 648    True  True  True     True     True     True  True  True  True  True
#
# ...

# %%
cs1.notnull().sum()
# Out:
# school        649
# sex           649
# age           649
# address       649
# famsize       649
# Pstatus       649
# Medu          649
# Fedu          649
# Mjob          649
# Fjob          649
# reason        649
# guardian      649
# traveltime    649
# studytime     649
# failures      649
# schoolsup     649
# famsup        649
# paid          649
# activities    649
# nursery       649
# higher        649
# internet      649
# romantic      649
# famrel        649
# freetime      649
# goout         649
# Dalc          649
# Walc          649
# health        649
# absences      649
# G1            649
# G2            649
# G3            649
# dtype: int64

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv' )
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
cs1.replace(to_replace='gp',value='hp')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.replace(to_replace='GP',value='hp')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       hp   F   18       U     GT3       A     4     4   at_home   teacher
# 1       hp   F   17       U     GT3       T     1     1   at_home     other
# 2       hp   F   15       U     LE3       T     1     1   at_home     other
# 3       hp   F   15       U     GT3       T     4     2    health  services
# 4       hp   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs1.replace({'Mjob':'other'},value='none')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3      none     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1      none     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs2=cs1.head(10)

# %%
cs2
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
 cs2.loc()

# %%
cs2.loc(0)

# %%
cs2.loc(1)

# %%
cs2
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
cs1.loc(1)

# %%
cs1.loc[1]
# Out:
# school             GP
# sex                 F
# age                17
# address             U
# famsize           GT3
# Pstatus             T
# Medu                1
# Fedu                1
# Mjob          at_home
# Fjob            other
# reason         course
# guardian       father
# traveltime          1
# studytime           2
# failures            0
# schoolsup          no
# famsup            yes
# paid               no
# activities         no
# nursery            no
# higher            yes
# internet          yes
# romantic           no
# famrel              5
# freetime            3
# goout               3
# Dalc                1
# Walc                1
# health              3
# absences            2
# G1                  9
# G2                 11
# G3                 11
# Name: 1, dtype: object

# %%
cs2
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
cs2.loc[1]
# Out:
# school             GP
# sex                 F
# age                17
# address             U
# famsize           GT3
# Pstatus             T
# Medu                1
# Fedu                1
# Mjob          at_home
# Fjob            other
# reason         course
# guardian       father
# traveltime          1
# studytime           2
# failures            0
# schoolsup          no
# famsup            yes
# paid               no
# activities         no
# nursery            no
# higher            yes
# internet          yes
# romantic           no
# famrel              5
# freetime            3
# goout               3
# Dalc                1
# Walc                1
# health              3
# absences            2
# G1                  9
# G2                 11
# G3                 11
# Name: 1, dtype: object

# %%
cs2.loc[[1,6]]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  ...  \
# 1     GP   F   17       U     GT3       T     1     1  at_home  other  ...
# 6     GP   M   16       U     LE3       T     2     2    other  other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1      5        3      3     1     1      3        2   9  11  11
# 6      4        4      4     1     1      3        0  13  12  13
#
# [2 rows x 33 columns]

# %%
cs2.loc[6,'Medu']
# Out:
# 2

# %%
cs1=pd.read_csv('C:\\Users\\Admin\\Downloads\\student-por.csv' )
cs1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
cs=cs1.head()

# %%
cs
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
cs.groupby('Medu').get_group(1)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  ...  \
# 1     GP   F   17       U     GT3       T     1     1  at_home  other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home  other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
#
# [2 rows x 33 columns]
